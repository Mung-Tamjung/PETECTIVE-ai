# %% [markdown]
# <a href="https://colab.research.google.com/github/Mung-Tamjung/PETECTIVE-ai/blob/main/dog_breeds_traning_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd "/content/drive/MyDrive"
# !pip install -U -r yolov5/requirements.txt
# Out:
# /content/drive/MyDrive
# ...
#   Using cached numpy-2.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (19.3 MB)
# ...

# %%
# %cd "/content/drive/MyDrive/dataset"
# Out:
# /content/drive/MyDrive/dataset

# %%
# !curl -L "https://app.roboflow.com/ds/iokNUbiQVy?key=lo6AMIsLtP" > roboflow.zip; unzip roboflow.zip; rm roboflow.zip
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#  extracting: train/images/Retriever25_jpg.rf.b42e51d8a3e81b57fe9a58c38a43b24b.jpg
#  extracting: train/images/Retriever25_jpg.rf.e8ed1a8ca463143c13e0a725f23de0c0.jpg
#  extracting: train/images/Retriever26_jpg.rf.0fb91f8e27079d3125ae877df5a1f45d.jpg
#  extracting: train/images/Retriever26_jpg.rf.25b9faddd68fa48aa5acefb9b81ee509.jpg
#  extracting: train/images/Retriever26_jpg.rf.b630154887c185c66fbf2d72581a6087.jpg
#  extracting: train/images/Retriever28_jpg.rf.2587b7c72452021b25ecdf387a1d8b5c.jpg
#  extracting: train/images/Retriever28_jpg.rf.db3aa1dddc8552d53de53caa610cbded.jpg
#  extracting: train/images/Retriever28_jpg.rf.ea8b6da37e039b3357eff7903c6c48e4.jpg
#  extracting: train/images/Retriever29_jpeg.rf.2114bad06edc89b32acd407cde969694.jpg
#  extracting: train/images/Retriever29_jpeg.rf.55ca9329c6543acd5104198d499c9f69.jpg
#  extracting: train/images/Retriever29_jpeg.rf.d08961b4cf027fd1836eb2ce725f7efe.jpg
# ...

# %%
from glob import glob

# 이미지 경로 list로 넣기
train_img_list = glob('/content/drive/MyDrive/dataset/train/images/*.jpg') + glob('/content/drive/MyDrive/dataset/train/images/*.jpeg') + glob('/content/drive/MyDrive/dataset/train/images/*.png')
valid_img_list = glob('/content/drive/MyDrive/dataset/valid/images/*.jpg') + glob('/content/drive/MyDrive/dataset/valid/images/*.jpeg') + glob('./content/drive/MyDrive/dataset/valid/images/*.png')
test_img_list = glob('/content/drive/MyDrive/dataset/test/images/*.jpg') + glob('/content/drive/MyDrive/dataset/test/images/*.jpeg') + glob('./content/drive/MyDrive/dataset/test/images/*.png')


# txt 파일에 write
with open('/content/drive/MyDrive/dataset/train.txt', 'w') as f:
	f.write('\n'.join(train_img_list) + '\n')

with open('/content/drive/MyDrive/dataset/valid.txt', 'w') as f:
	f.write('\n'.join(valid_img_list) + '\n')

with open('/content/drive/MyDrive/dataset/test.txt', 'w') as f:
	f.write('\n'.join(test_img_list) + '\n')

# %%
import yaml

with open('/content/drive/MyDrive/dataset/data.yaml', 'r') as f:
	data = yaml.safe_load(f)

print(data)

data['train'] = '/content/drive/MyDrive/dataset/train.txt'
data['val'] = '/content/drive/MyDrive/dataset/valid.txt'
data['test'] = '/content/drive/MyDrive/dataset/test.txt'

with open('/content/drive/MyDrive/dataset/data.yaml', 'w') as f:
	yaml.dump(data, f)
# Out:
# {'train': '../train/images', 'val': '../valid/images', 'test': '../test/images', 'nc': 9, 'names': ['Bichon', 'Chihuahua', 'Jindo', 'Maltese', 'Pomeranian', 'Poodle', 'Retriever', 'Shihtzu', 'YorkshireTerrier'], 'roboflow': {'workspace': 'petective', 'project': 'dog-breeds-heriv', 'version': 8, 'license': 'CC BY 4.0', 'url': 'https://universe.roboflow.com/petective/dog-breeds-heriv/dataset/8'}}

# %%
# %cd /content/drive/MyDrive/yolov5
# Out:
# /content/drive/MyDrive/yolov5

# %%
# !python train.py --img 640 --batch 16 --epochs 50 --data /content/drive/MyDrive/dataset/data.yaml \
--cfg ./models/yolov5s.yaml --weights yolov5s.pt --name dog_breeds_training_6
# Out:
# 2024-07-21 08:46:53.797481: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-21 08:46:53.797542: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-21 08:46:53.799006: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python /content/drive/MyDrive/yolov5/detect.py --weights /content/drive/MyDrive/yolov5/runs/train/dog_breeds_training_6/weights/best.pt --img 640 --conf 0.5 --source /content/drive/MyDrive/testimage/testimage20.jpg
# Out:
# detect: weights=['/content/drive/MyDrive/yolov5/runs/train/dog_breeds_training_6/weights/best.pt'], source=/content/drive/MyDrive/testimage/testimage20.jpg, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-321-g3742ab49 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7034398 parameters, 0 gradients, 15.8 GFLOPs
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/1 /content/drive/MyDrive/testimage/testimage20.jpg: 640x544 1 Retriever, 104.5ms
# ...

# %%
# !python /content/drive/MyDrive/yolov5/detect.py --weights /content/drive/MyDrive/yolov5/runs/train/dog_breeds_training_6/weights/best.pt --img 640 --conf 0.5 --source /content/drive/MyDrive/testimage/testimage21.jpg
# Out:
# detect: weights=['/content/drive/MyDrive/yolov5/runs/train/dog_breeds_training_6/weights/best.pt'], source=/content/drive/MyDrive/testimage/testimage21.jpg, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-321-g3742ab49 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7034398 parameters, 0 gradients, 15.8 GFLOPs
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/1 /content/drive/MyDrive/testimage/testimage21.jpg: 640x448 1 YorkshireTerrier, 103.7ms
# ...

# %%
# !python /content/drive/MyDrive/yolov5/detect.py --weights /content/drive/MyDrive/yolov5/runs/train/dog_breeds_training_6/weights/best.pt --img 640 --conf 0.5 --source /content/drive/MyDrive/testimage/testimage22.jpg
# Out:
# detect: weights=['/content/drive/MyDrive/yolov5/runs/train/dog_breeds_training_6/weights/best.pt'], source=/content/drive/MyDrive/testimage/testimage22.jpg, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-321-g3742ab49 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7034398 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/drive/MyDrive/testimage/testimage22.jpg: 480x640 (no detections), 103.5ms
# Speed: 0.7ms pre-process, 103.5ms inference, 29.9ms NMS per image at shape (1, 3, 640, 640)
# ...

# %% [markdown]
# **testimage22 (진돗개) 검출 x**

# %%
# !python /content/drive/MyDrive/yolov5/detect.py --weights /content/drive/MyDrive/yolov5/runs/train/dog_breeds_training_6/weights/best.pt --img 640 --conf 0.5 --source /content/drive/MyDrive/testimage/testimage24.jpg
# Out:
# detect: weights=['/content/drive/MyDrive/yolov5/runs/train/dog_breeds_training_6/weights/best.pt'], source=/content/drive/MyDrive/testimage/testimage24.jpg, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-321-g3742ab49 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7034398 parameters, 0 gradients, 15.8 GFLOPs
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/1 /content/drive/MyDrive/testimage/testimage24.jpg: 448x640 1 Jindo, 104.4ms
# Speed: 0.7ms pre-process, 104.4ms inference, 667.6ms NMS per image at shape (1, 3, 640, 640)
# ...

# %%
# !python /content/drive/MyDrive/yolov5/detect.py --weights /content/drive/MyDrive/yolov5/runs/train/dog_breeds_training_6/weights/best.pt --img 640 --conf 0.5 --source /content/drive/MyDrive/testimage/testimage23.jpg
# Out:
# detect: weights=['/content/drive/MyDrive/yolov5/runs/train/dog_breeds_training_6/weights/best.pt'], source=/content/drive/MyDrive/testimage/testimage23.jpg, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-321-g3742ab49 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7034398 parameters, 0 gradients, 15.8 GFLOPs
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/1 /content/drive/MyDrive/testimage/testimage23.jpg: 640x480 1 Shihtzu, 103.8ms
# Speed: 0.7ms pre-process, 103.8ms inference, 641.0ms NMS per image at shape (1, 3, 640, 640)
# ...
